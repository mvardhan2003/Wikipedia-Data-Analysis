# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("wikipedias.csv")

# %%
df
# Out:
#       No          Language       Language (local) Wiki   Articles   All pages  \
# 0      1           English                English   en  7,085,394  64,396,510
# 1      2           Cebuano                Cebuano  ceb  6,115,897  11,230,118
# 2      3            German                Deutsch   de  3,066,100   8,411,906
# 3      4            French               français   fr  2,718,476  13,712,452
# 4      5           Swedish                svenska   sv  2,619,400   6,339,529
# ..   ...               ...                    ...  ...        ...         ...
# 338  339     South Ndebele    isiNdebele seSewula   nr        266         836
# 339  340       Kalaallisut            kalaallisut   kl        245       2,290
# 340  341  West Coast Bajau             Bajau Sama  bdr        236       1,315
# 341  342             Tigre                    ትግሬ  tig         44         478
# 342  343              Cree  Nēhiyawēwin / ᓀᐦᐃᔭᐍᐏᐣ   cr         14       2,342
#
# ...

# %%
df.describe()
# Out:
#                No      Admins
# count  343.000000  343.000000
# mean   172.000000   10.052478
# std     99.159804   47.446216
# min      1.000000    0.000000
# 25%     86.500000    1.000000
# 50%    172.000000    3.000000
# 75%    257.500000    6.000000
# max    343.000000  829.000000

# %%
df.isnull().sum()
# Out:
# No                  0
# Language            0
# Language (local)    0
# Wiki                0
# Articles            0
# All pages           0
# Edits               0
# Admins              0
# Users               0
# Active users        0
# Files               0
# Depth               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 343 entries, 0 to 342
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   No                343 non-null    int64
#  1   Language          343 non-null    object
#  2   Language (local)  343 non-null    object
#  3   Wiki              343 non-null    object
#  4   Articles          343 non-null    object
#  5   All pages         343 non-null    object
#  6   Edits             343 non-null    object
#  7   Admins            343 non-null    int64
#  8   Users             343 non-null    object
#  9   Active users      343 non-null    object
#  10  Files             343 non-null    object
#  11  Depth             343 non-null    object
# dtypes: int64(2), object(10)
# memory usage: 32.3+ KB

# %%
cols = ['Articles', 'All pages','Edits', 'Users', 'Active users', 'Files', 'Depth']
cols
# Out:
# ['Articles', 'All pages', 'Edits', 'Users', 'Active users', 'Files', 'Depth']

# %%
for c in cols:
    df[c] = df[c].astype(str).str.replace(',','',regex=False).astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 343 entries, 0 to 342
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   No                343 non-null    int64
#  1   Language          343 non-null    object
#  2   Language (local)  343 non-null    object
#  3   Wiki              343 non-null    object
#  4   Articles          343 non-null    int64
#  5   All pages         343 non-null    int64
#  6   Edits             343 non-null    int64
#  7   Admins            343 non-null    int64
#  8   Users             343 non-null    int64
#  9   Active users      343 non-null    int64
#  10  Files             343 non-null    int64
#  11  Depth             343 non-null    int64
# dtypes: int64(9), object(3)
# memory usage: 32.3+ KB

# %%
df.columns
# Out:
# Index(['No', 'Language', 'Language (local)', 'Wiki', 'Articles', 'All pages',
#        'Edits', 'Admins', 'Users', 'Active users', 'Files', 'Depth'],
#       dtype='object')

# %%
for c in ["Language","Language (local)","Wiki"]:
    df[c] = df[c].astype(str)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 343 entries, 0 to 342
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   No                343 non-null    int64
#  1   Language          343 non-null    object
#  2   Language (local)  343 non-null    object
#  3   Wiki              343 non-null    object
#  4   Articles          343 non-null    int64
#  5   All pages         343 non-null    int64
#  6   Edits             343 non-null    int64
#  7   Admins            343 non-null    int64
#  8   Users             343 non-null    int64
#  9   Active users      343 non-null    int64
#  10  Files             343 non-null    int64
#  11  Depth             343 non-null    int64
# dtypes: int64(9), object(3)
# memory usage: 32.3+ KB

# %%
df
# Out:
#       No          Language       Language (local) Wiki  Articles  All pages  \
# 0      1           English                English   en   7085394   64396510
# 1      2           Cebuano                Cebuano  ceb   6115897   11230118
# 2      3            German                Deutsch   de   3066100    8411906
# 3      4            French               français   fr   2718476   13712452
# 4      5           Swedish                svenska   sv   2619400    6339529
# ..   ...               ...                    ...  ...       ...        ...
# 338  339     South Ndebele    isiNdebele seSewula   nr       266        836
# 339  340       Kalaallisut            kalaallisut   kl       245       2290
# 340  341  West Coast Bajau             Bajau Sama  bdr       236       1315
# 341  342             Tigre                    ትግሬ  tig        44        478
# 342  343              Cree  Nēhiyawēwin / ᓀᐦᐃᔭᐍᐏᐣ   cr        14       2342
#
# ...

# %%
df.describe()
# Out:
#                No      Articles     All pages         Edits      Admins  \
# count  343.000000  3.430000e+02  3.430000e+02  3.430000e+02  343.000000
# mean   172.000000  1.919660e+05  7.919480e+05  1.103816e+07   10.052478
# std     99.159804  6.470675e+05  3.913016e+06  7.555664e+07   47.446216
# min      1.000000  1.400000e+01  4.780000e+02  4.842000e+03    0.000000
# 25%     86.500000  2.600000e+03  6.886500e+03  6.274150e+04    1.000000
# 50%    172.000000  1.132700e+04  2.821200e+04  2.209750e+05    3.000000
# 75%    257.500000  7.536250e+04  1.830675e+05  1.453839e+06    6.000000
# max    343.000000  7.085394e+06  6.439651e+07  1.315740e+09  829.000000
#
#               Users   Active users          Files          Depth
# count  3.430000e+02     343.000000     343.000000     343.000000
# mean   3.585479e+05    1329.565598    8365.790087    1497.839650
# std    2.782010e+06    7460.901945   55851.700392   26122.537885
# ...

# %%
df[['Language','Language (local)','Wiki']].value_counts()
# Out:
# Language    Language (local)  Wiki
# Zulu        isiZulu           zu         1
# Abkhazian   аԥсшәа            ab         1
# Acehnese    Acèh              ace        1
# Adyghe      адыгабзэ          ady        1
# Afrikaans   Afrikaans         af         1
#                                         ..
# Bangla      বাংলা             bn         1
# Banjar      Banjar            bjn        1
# Banyumasan  Basa Banyumasan   map-bms    1
# Bashkir     башҡортса         ba         1
# Basque      euskara           eu         1
# Name: count, Length: 343, dtype: int64

# %%
df
# Out:
#       No          Language       Language (local) Wiki  Articles  All pages  \
# 0      1           English                English   en   7085394   64396510
# 1      2           Cebuano                Cebuano  ceb   6115897   11230118
# 2      3            German                Deutsch   de   3066100    8411906
# 3      4            French               français   fr   2718476   13712452
# 4      5           Swedish                svenska   sv   2619400    6339529
# ..   ...               ...                    ...  ...       ...        ...
# 338  339     South Ndebele    isiNdebele seSewula   nr       266        836
# 339  340       Kalaallisut            kalaallisut   kl       245       2290
# 340  341  West Coast Bajau             Bajau Sama  bdr       236       1315
# 341  342             Tigre                    ትግሬ  tig        44        478
# 342  343              Cree  Nēhiyawēwin / ᓀᐦᐃᔭᐍᐏᐣ   cr        14       2342
#
# ...

# %%
top_10_articles = df.nlargest(10,"Articles")[["Language","Articles"]]
top_10_articles
# Out:
#   Language  Articles
# 0  English   7085394
# 1  Cebuano   6115897
# 2   German   3066100
# 3   French   2718476
# 4  Swedish   2619400
# 5    Dutch   2201291
# 6  Spanish   2072047
# 7  Russian   2070080
# 8  Italian   1942936
# 9   Polish   1673794

# %%
df[df["Language"]=="Telugu"]
# Out:
#     No Language Language (local) Wiki  Articles  All pages    Edits  Admins  \
# 69  70   Telugu           తెలుగు   te    116702     398998  4563538      11
#
#      Users  Active users  Files  Depth
# 69  140083           427  14715     66

# %%
df.to_csv("Wikipedia_processed.csv")

# %% [markdown]
# # Problem Statment
# **Decoupling Quantity from Quality in Global Wikipedia Data**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(6,6))
sns.boxplot(y=df["Articles"])
plt.title("Box plot of Articles")
# Out:
# Text(0.5, 1.0, 'Box plot of Articles')

# %%
top_10_edits = df.nlargest(10,"Edits")[["Language","Edits"]]
top_10_edits
# Out:
#       Language       Edits
# 0      English  1315739516
# 2       German   259348405
# 3       French   229907583
# 6      Spanish   169859793
# 7      Russian   149296521
# 8      Italian   147279340
# 12    Japanese   106905368
# 11     Chinese    89498480
# 9       Polish    77760016
# 14  Vietnamese    74290987

# %%
top_10_users = df.nlargest(10,"Users")[["Language","Users"]]
top_10_users
# Out:
#       Language     Users
# 0      English  49932265
# 6      Spanish   7524848
# 3       French   5436542
# 2       German   4799705
# 11     Chinese   3876797
# 7      Russian   3822608
# 17  Portuguese   3306449
# 15      Arabic   2815338
# 8      Italian   2737042
# 12    Japanese   2456877

# %%
top_10_activeusers = df.nlargest(10,"Active users")[["Language","Active users"]]
top_10_activeusers
# Out:
#     Language  Active users
# 0    English        115920
# 3     French         41010
# 2     German         38742
# 8    Italian         30722
# 12  Japanese         26155
# 11   Chinese         16964
# 6    Spanish         12438
# 9     Polish         11441
# 18   Persian         10853
# 15    Arabic          8944

# %%
plt.figure(figsize=(8,5))

sns.histplot(df['Articles'][:10], bins=20, color='red')        # histogram
sns.kdeplot(df['Articles'][:10], color='green', linewidth=3)   # smooth line

plt.show()

# %%
sns.boxplot(df.iloc[:50,:],y="Depth")
# Out:
# <Axes: ylabel='Depth'>

# %%
df[df['Articles']<50000]["Articles"].plot(kind="box")
# Out:
# <Axes: >

# %%
df
# Out:
#       No          Language       Language (local) Wiki  Articles  All pages  \
# 0      1           English                English   en   7085394   64396510
# 1      2           Cebuano                Cebuano  ceb   6115897   11230118
# 2      3            German                Deutsch   de   3066100    8411906
# 3      4            French               français   fr   2718476   13712452
# 4      5           Swedish                svenska   sv   2619400    6339529
# ..   ...               ...                    ...  ...       ...        ...
# 338  339     South Ndebele    isiNdebele seSewula   nr       266        836
# 339  340       Kalaallisut            kalaallisut   kl       245       2290
# 340  341  West Coast Bajau             Bajau Sama  bdr       236       1315
# 341  342             Tigre                    ትግሬ  tig        44        478
# 342  343              Cree  Nēhiyawēwin / ᓀᐦᐃᔭᐍᐏᐣ   cr        14       2342
#
# ...

# %%
plt.plot(df['Language'][:10],df['Depth'][:10])

# %%
plt.pie(df['Articles'][:10],labels=df['Language'][:10],autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x20caef4a690>,
# ...
#  [Text(0.8376416279337067, 0.7129912363785196, 'English'),
#   Text(-0.47674262878546037, 0.9913205666678812, 'Cebuano'),
#   Text(-1.0761356833648472, 0.22788591660932758, 'German'),
#   Text(-1.0267338500446788, -0.3947373825373411, 'French'),
#   Text(-0.6852372424341145, -0.8604939985736628, 'Swedish'),
#   Text(-0.2106743653017681, -1.0796371204273671, 'Dutch'),
#   Text(0.2535557780379428, -1.0703781889704096, 'Spanish'),
#   Text(0.6611845613327193, -0.87911033201485, 'Russian'),
#   Text(0.9510024044319347, -0.552805957605993, 'Italian'),
#   Text(1.084772143832528, -0.18239900209425952, 'Polish')],
#  [Text(0.45689543341838534, 0.3889043107519197, '22.45%'),
#   Text(-0.26004143388297835, 0.5407203090915714, '19.38%'),
#   Text(-0.5869831000171893, 0.12430140905963322, '9.71%'),
#   Text(-0.5600366454789156, -0.21531129956582237, '8.61%'),
#   Text(-0.37376576860042604, -0.46936036285836147, '8.30%'),
# ...

# %% [markdown]
# **Observation:**
# The big chunk of articles in wikipedia are from these countries with english and cebuano contributing 43% of top 10 countries

# %%
plt.pie(df['Active users'][:10],labels=df['Language'][:10],autopct='%1.2f%%',radius= 1.4)
# Out:
# ([<matplotlib.patches.Wedge at 0x20cb22b07a0>,
# ...
#  [Text(0.35608350368111263, 1.4982671785787016, 'English'),
#   Text(-1.3767267805869343, 0.6900893939300436, 'Cebuano'),
#   Text(-1.5398118168094048, 0.02407423548360192, 'German'),
#   Text(-0.9518061813457963, -1.210646518663451, 'French'),
#   Text(-0.2051699507041039, -1.526271696431561, 'Swedish'),
#   Text(0.04442371039450073, -1.539359130922601, 'Dutch'),
#   Text(0.4187096412125496, -1.481985909634656, 'Spanish'),
#   Text(0.7495895647552453, -1.3452566611654602, 'Russian'),
#   Text(1.2547386724573182, -0.8928778549387629, 'Italian'),
#   Text(1.5266022578315124, -0.20269569897688733, 'Polish')],
#  [Text(0.19422736564424326, 0.81723664286111, '42.57%'),
#   Text(-0.750941880320146, 0.3764123966891147, '0.06%'),
#   Text(-0.8398973546233117, 0.013131401172873773, '14.23%'),
#   Text(-0.5191670080067979, -0.6603526465437004, '15.06%'),
#   Text(-0.11191088220223848, -0.8325118344172151, '1.89%'),
# ...

# %% [markdown]
# **Observation:**
# We can see that the big chunk of active users are form english which is proportional to its articles but for ceabuna with 2nd highest articles the active users dosen't macth it is because of Lsjbot which is wikipedia article creation bot used to write many articles and almost all articles of some laungugae are written bu the bot and it was stopped by admins after some time

# %%
Indian_launguages = ["Assamese", "Bengali", "Gujarati", "Hindi","Marathi","Oriya", "Punjabi", "Sanskrit","Kannada", "Malayalam", "Tamil","Telugu"
]
Indian_launguages
# Out:
# ['Assamese',
#  'Bengali',
#  'Gujarati',
#  'Hindi',
#  'Marathi',
#  'Oriya',
#  'Punjabi',
#  'Sanskrit',
#  'Kannada',
#  'Malayalam',
#  'Tamil',
#  'Telugu']

# %%
df_india_major = df[df['Language'].isin(Indian_launguages)]
df_india_major
# Out:
#       No   Language Language (local) Wiki  Articles  All pages    Edits  \
# 58    59      Tamil            தமிழ்   ta    178145     607064  4388008
# 62    63      Hindi           हिन्दी   hi    167165    1381865  6480262
# 69    70     Telugu           తెలుగు   te    116702     398998  4563538
# 75    76    Marathi            मराठी   mr    100679     325227  2622435
# 81    82  Malayalam           മലയാളം   ml     87348     547518  4325349
# 101  102    Punjabi           ਪੰਜਾਬੀ   pa     59154     189766   821697
# 113  114    Kannada            ಕನ್ನಡ   kn     34010     157597  1312922
# 116  117   Gujarati          ગુજરાતી   gu     30707     134432   891741
# 135  136   Assamese          অসমীয়া   as     19919     114909   547401
# 162  163   Sanskrit        संस्कृतम्   sa     12403      81079   495754
#
#      Admins   Users  Active users  Files  Depth
# 58       32  248904           650   9531     41
# 62        7  875066          1441   4643    247
# ...

# %%
edf= df_india_major.merge(df_india_major)
edf
# Out:
#     No   Language Language (local) Wiki  Articles  All pages    Edits  Admins  \
# 0   59      Tamil            தமிழ்   ta    178145     607064  4388008      32
# 1   63      Hindi           हिन्दी   hi    167165    1381865  6480262       7
# 2   70     Telugu           తెలుగు   te    116702     398998  4563538      11
# 3   76    Marathi            मराठी   mr    100679     325227  2622435      10
# 4   82  Malayalam           മലയാളം   ml     87348     547518  4325349      14
# 5  102    Punjabi           ਪੰਜਾਬੀ   pa     59154     189766   821697      10
# 6  114    Kannada            ಕನ್ನಡ   kn     34010     157597  1312922       5
# 7  117   Gujarati          ગુજરાતી   gu     30707     134432   891741       3
# 8  136   Assamese          অসমীয়া   as     19919     114909   547401       6
# 9  163   Sanskrit        संस्कृतम्   sa     12403      81079   495754       3
#
#     Users  Active users  Files  Depth
# 0  248904           650   9531     41
# ...

# %%
df['Depth'].describe()
# Out:
# count       343.000000
# mean       1497.839650
# std       26122.537885
# min           0.000000
# 25%           8.500000
# 50%          28.000000
# 75%          75.500000
# max      483867.000000
# Name: Depth, dtype: float64

# %%
df[df['Depth']==df['Depth'].max()]
# Out:
#       No Language       Language (local) Wiki  Articles  All pages  Edits  \
# 342  343     Cree  Nēhiyawēwin / ᓀᐦᐃᔭᐍᐏᐣ   cr        14       2342  40983
#
#      Admins  Users  Active users  Files   Depth
# 342       2  22495            25      0  483867

# %%
sns.pairplot(df)

# %%
df
# Out:
#       No          Language       Language (local) Wiki  Articles  All pages  \
# 0      1           English                English   en   7085394   64396510
# 1      2           Cebuano                Cebuano  ceb   6115897   11230118
# 2      3            German                Deutsch   de   3066100    8411906
# 3      4            French               français   fr   2718476   13712452
# 4      5           Swedish                svenska   sv   2619400    6339529
# ..   ...               ...                    ...  ...       ...        ...
# 338  339     South Ndebele    isiNdebele seSewula   nr       266        836
# 339  340       Kalaallisut            kalaallisut   kl       245       2290
# 340  341  West Coast Bajau             Bajau Sama  bdr       236       1315
# 341  342             Tigre                    ትግሬ  tig        44        478
# 342  343              Cree  Nēhiyawēwin / ᓀᐦᐃᔭᐍᐏᐣ   cr        14       2342
#
# ...

# %% [markdown]
# **Top 10 launges by no of articles**

# %%
sns.barplot(x='Language',y='Articles',data = df[:10])
plt.yscale("log")

# %%
sns.scatterplot(x='Articles',y='Users',data=df)
plt.yscale('log')
plt.xscale('log')

# %% [markdown]
# **We can See That as the number of articles increases the no of users increase and that for some launguages even though the articles are high the users are less which is because of Ljbot**

# %%
sns.regplot(x='Articles', y='Edits', data=df)
plt.yscale('log')
plt.xscale('log')

# %%
df_numeric = df.iloc[:, 4:]
plt.figure(figsize=(8,8))
sns.heatmap(df_numeric.corr(), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# **Correlation between all numerical Features**
